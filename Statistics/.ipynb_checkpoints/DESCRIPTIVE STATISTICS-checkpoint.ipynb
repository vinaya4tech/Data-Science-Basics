# %% [markdown]
# ## DESCRIPTIVE STATISTICS
#
# Descriptive Statistical Analysis helps you to understand your data and is a very important part of Machine Learning.
# This is due to Machine Learning being all about making predictions.
#
# it provides information on summary statistics that includes Mean,
# Standard Error, Median, Mode, Standard Deviation, Variance, Kurtosis,
# Skewness, Range, Minimum, Maximum, Sum, and Count.
# Descriptive statistics involve evaluating measures of center(centrality measures) and measures of dispersion(spread)
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Normal Distribution:
#        A normal Distribution is given if your data is symmetrical, bell-shaped, centered and unimodal.
#        In a perfect normal distribution, each side is an exact mirror of the other.
#        It should look like the distribution on the picture below
#   ![image.png](attachment:image.png)

# %% [markdown]
# ## Measure of Central Tendency

# %% [markdown]
# It  describes a whole set of data with a single value that represents the centre of its distribution.
# There are three main measures of central tendency: the mode, the median and the mean.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Mean
# It is the sum of the observations divided by the sample size

# %% [markdown]
# Samples =[5,6,6,8,9,9,9,9,10,10 ]
# mean = (5+6+6+8+9+9+9+9+10+10)/10 = 8.1

# %%
# using python numpy 
import numpy as np
Samples =[5,6,6,8,9,9,9,9,10,10 ]
mean = np.mean(Samples)
mean
# Out:
# 8.1

# %% [markdown]
# ##### Limitation :
# It is affected by extreme values. Very large or very small numbers can distort the answer

# %% [markdown]
# ### Median
# It is the middle value. It splits the data in half. Half of the data are above the median; half of the data are below the median.

# %%
Samples =[5,6,6,8,9,9,9,9,10,10 ]
median = np.median(Samples)
median
# Out:
# 9.0

# %% [markdown]
# #### Advantage :
# It is NOT affected by extreme values. Very large or very small numbers does not affect it

# %% [markdown]
# ### Mode
# It is the value that occurs most frequently in a dataset

# %%
import statistics
samples =[1,2,3,2,5,7,2,3]
mode= statistics.mode(samples)
mode
# Out:
# 2

# %% [markdown]
# #### Advantage :
#    It can be used when the data is not numerical.
#
# #### Disadvantage :
#   1. There may be no mode at all if none of the data is the same
#   2. There may be more than one mode

# %% [markdown]
# ### Measure of Dispersion

# %% [markdown]
# There are four main measures of variability: Range, Inter quartile range, Standard deviation and Variance.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Range
#     It is simply the largest observation minus the smallest observation.
#
#
#
#     Advantage:
#     It is easy to calculate.
#
#     Disadvantage:
#     It is very sensitive to outliers and does not use all the observations in a data set

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A=np.array([[10,14,11,7,9.5,15,19],[8,9,17,14.5,12,18,15.5],
    [15,7.5,11.5,10,10.5,7,11],[11.5,11,9,12,14,12,7.5]])
B=A.T
B
# Out:
# array([[10. ,  8. , 15. , 11.5],
#        [14. ,  9. ,  7.5, 11. ],
#        [11. , 17. , 11.5,  9. ],
#        [ 7. , 14.5, 10. , 12. ],
#        [ 9.5, 12. , 10.5, 14. ],
#        [15. , 18. ,  7. , 12. ],
#        [19. , 15.5, 11. ,  7.5]])

# %%
a=np.ptp(B, axis=0)
b=np.ptp(B,axis=1)
print(a)
print(b)
# Out:
# [12.  10.   8.   6.5]
# [ 7.   6.5  8.   7.5  4.5 11.  11.5]

# %% [markdown]
# #### Standard Deviation
#     It is a measure of spread of data about the mean.
#     The Standard Deviation is a measure of how spread out numbers are.
#     Its symbol is σ (the greek letter sigma)
#     The formula is easy: it is the square root of the Variance
#         Advantage :
#         It gives a better picture of your data than just the mean alone.
#         Disadvantage :
#         1. It doesn't give a clear picture about the whole range of the data.
#         2. It can give a skewed picture if data contain outliers.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Variance :
#    The average of the squared differences from the Mean.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The heights (at the shoulders) are: 600mm, 470mm, 170mm, 430mm and 300mm.
#
# Find out the Mean, the Variance, and the Standard Deviation.
#
# Your first step is to find the Mean:
#
# Answer:
# Mean	=	 (600 + 470 + 170 + 430 + 300)/5
#  	=	 1970/5
#  	=	394

# %%
# using python 
mean= statistics.mean([600 , 470 , 170 , 430 , 300])
mean
# Out:
# 394

# %% [markdown]
# so the mean (average) height is 394 mm. Let's plot this on the chart:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# σ2	=	 (206^2 + 76^2 + (−224)^2+ 362 + (−94)^2)/5
# σ2=21704
#
# So the Variance is 21,704

# %%
Variance = np.var([600 , 470 , 170 , 430 , 300])
Variance
# Out:
# 21704.0

# %% [markdown]
# Standard Deviation
# σ	=	√21704
#  	=	147.32...
#  	=	147 (to the nearest mm)

# %%
# using python 
StandardDeviation  = np.std([600 , 470 , 170 , 430 , 300])
StandardDeviation
# Out:
# 147.32277488562318

# %% [markdown]
# And the good thing about the Standard Deviation is that it is useful. Now we can show which heights are within one Standard Deviation (147mm) of the Mean:
#
# ![image.png](attachment:image.png)
#
# So, using the Standard Deviation we have a "standard" way of knowing what is normal, and what is extra large or extra small.

# %% [markdown]
# ## When to use mean, median and mode?
#
# Mean – When your data is not skewed i.e normally distributed. In other words, there are no extreme values present in the data set (Outliers).
#
# Median – When your data is skewed or you are dealing with ordinal (ordered categories) data (e.g. likert scale 1. Strongly dislike 2. Dislike 3.Neutral   4. Like 5. Strongly like)
#
# Mode - When dealing with nominal (unordered categories) data.

# %% [markdown]
# ## Modality
#     The modality of a distribution is determined by the number of peaks it contains.
#     Most distributions have only one peak but it is possible that you encounter distributions with two or more peaks.
#     The picture below shows visual examples of the three types of modality:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Unimodal means that the distribution has only one peak, which means it has only one frequently occurring score,clustered at the top.
#
# A bimodal distribution has two values that occur frequently (two peaks)
#
# A multimodal has two or several frequently occurring values.
